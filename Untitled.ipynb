# %%
import pandas as pd

# %%
data = pd.read_csv('top_rated_tv.csv')
# Out:
# The file 'operator.py' seems to be overriding built in modules and interfering with the startup of the kernel. Consider renaming the file and starting the kernel again.
#
# Click <a href='https://aka.ms/kernelFailuresOverridingBuiltInModules'>here</a> for more info.

# %%
data
# Out:
# The file 'operator.py' seems to be overriding built in modules and interfering with the startup of the kernel. Consider renaming the file and starting the kernel again.
#
# Click <a href='https://aka.ms/kernelFailuresOverridingBuiltInModules'>here</a> for more info.
